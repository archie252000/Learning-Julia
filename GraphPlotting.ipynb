# %%
using Plots

# %%
x = -10:0.3:10
f(x) = x^2
y = f.(x)
# Out:
# 67-element Vector{Float64}:
#  100.0
#   94.08999999999999
#   88.36000000000001
#   82.80999999999999
#   77.44000000000001
#   72.25
#   67.24
#   62.410000000000004
#   57.76
#   53.29
#    ⋮
#   54.760000000000005
#   59.290000000000006
#   64.0
#   68.89000000000001
#   73.96
#   79.21000000000001
#   84.63999999999999
#   90.25
#   96.04000000000002

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
plot(x, y, label = "line")
scatter!(x,y, lable="points")
